# %% [markdown]
# # Lab 5- Object Oriented Programming
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github//afarbin/DATA1401-Spring-2020/blob/master/Labs/Lab-5/Lab-5.ipynb)
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self,max_val):
        self.max_val=max_val
        self.cur_val=1
        
    def increment(self):
        if self.cur_val>self.max_val:
            print("Max value reached.")
        else:
            self.cur_val+=1
            
    def reset(self):
        self.cur_val=1

# %%
my_counter=counter(3)

# %%
my_counter.increment()
my_counter.increment()
my_counter.increment()
my_counter.increment()
my_counter.increment()
# Out:
# Max value reached.
# Max value reached.

# %%
my_counter.cur_val=100

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self,max_val):
        self.__max_val=max_val
        self.__cur_val=1
        
    def increment(self):
        if self.__cur_val>self.__max_val:
            print("Max value reached.")
        else:
            self.__cur_val+=1
            
    def reset(self):
        self.__cur_val=1
        
    def cur_val(self):
        return self.__cur_val

    def max_val(self):
        return self.__max_val

# %%
my_counter=counter(3)

# %%
my_counter.cur_val()
# Out:
# 1

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and parameter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class rectangle:
    def __init__(self,width,length,x,y):
        self.__width=width
        self.__length=legth
        self.__x=x
        self.__y=y
        
    def area(self):
        return self.__width*self.__length
    
    def perimeter(self):
        return 2*(self.__width+self.__length)
    
    def x(self):
        return self.__x
    
    def y(self):
        return self.__y

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and parameter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class circle:
  def __init__(self,radius,x,y):
    self.__radius=radius
    self.__x=x
    self.__y=y

  def area(self):
    return 3.141592*((self.__radius)**2)

  def circumference(self):
    return 3.141592*(2*self.__radius)

  def x(self):
    return self.__x

  def y(self):
    return self.__y

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as dummy functions. Re-implement those classes to inherit from the base class and overload the functions accordingly.

# %%
class coordinates:
  def __init__(self,x,y):
    self.__x=x
    self.__y=y

  def x(self):
    return self.__x

  def y(self):
    return self.__y

class circle:
  def __init__(self,radius,x,y):
    self.__radius=radius

  def cir_area(self):
    return 3.141592*((self.__radius)**2)

  def circumference(self):
    return 3.141592*(2*self.__radius)

class rectangle:
    def __init__(self,width,length,x,y):
        self.__width=width
        self.__length=legth
        
    def rec_area(self):
        return self.__width*self.__length
    
    def perimeter(self):
        return 2*(self.__width+self.__length)

# %% [markdown]
# 6. Implement an analogous triangle class.

# %%
class triangle:
  def __init__(self,base,height,x,y):
    self.__base=base
    self.__height=height
  
  def tri_area(self):
    return (self.__base*self.__height)/2

  def parameter(self):
    return

# %% [markdown]
# 7. Add a function to the object classes that test if a given set of $x$ and $y$ coordinates are inside of the object.

# %%
class coordinates:
  def __init__(self,x,y):
    self.x=x
    self.y=y

class circle(coordinates):
  def __init__(self,x,y,radius):
    super(circle,self).__init__(x,y)
    self.__radius=radius

  def cir_area(self):
    return 3.141592*((self.__radius)**2)

  def circumference(self):
    return 3.141592*(2*self.__radius)

  def in_circ(self,a,b):
    if (((a-self.x)**2)+((b-self.y)**2))**(1/2)<=self.__radius:
      print('In Circle')
    else: print('Not in Circle')


class rectangle(coordinates):
    def __init__(self,x,y,width,length):
        super(rectangle,self).__init__(x,y)
        self.__width=width
        self.__length=length
        
    def rec_area(self):
        return self.__width*self.__length
    
    def perimeter(self):
        return 2*(self.__width+self.__length)

    def in_rec(self,a,b):
        if a>=self.x and a<=self.x+self.__width:
          if b>=self.y and b<=self.y+self.__length:
            print('In Rectangle')
          else: print('Not in Rectangle')
        else: print('Not in Rectangle')

class triangle:
  def __init__(self,base,height):
    self.__base=base
    self.__height=height
  
  def tri_area(self):
    return (self.__base*self.__height)/2

  def parameter(self):
    return

# %%
shape=rectangle(2,0,3,4)
print(shape.rec_area())

shape.in_rec(0,0)
# Out:
# 12
# Not in Rectangle

# %%
shap=circle(3,2,5)
print(shap.cir_area())

shap.in_circ(2,6)
# Out:
# 78.5398
# In Circle

# %% [markdown]
# 8. Add a function to the object classes that return a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class coordinates:
  def __init__(self,x,y):
    self.x=x
    self.y=y

class circle(coordinates):
  def __init__(self,x,y,radius):
    super(circle,self).__init__(x,y)
    self.__radius=radius

  def cir_area(self):
    return 3.141592*((self.__radius)**2)

  def circumference(self):
    return 3.141592*(2*self.__radius)

  def in_circ(self,a,b):
    if (((a-self.x)**2)+((b-self.y)**2))**(1/2)<=self.__radius:
      print('In Circle')
    else: print('Not in Circle')


class rectangle(coordinates):
    def __init__(self,x,y,width,length):
        super(rectangle,self).__init__(x,y)
        self.__width=width
        self.__length=length
        self.__rec_points=list()
        
    def rec_area(self):
        return self.__width*self.__length
    
    def perimeter(self):
        return 2*(self.__width+self.__length)

    def in_rec(self,a,b):
        if a>=self.x and a<=self.x+self.__width:
          if b>=self.y and b<=self.y+self.__length:
            print('In Rectangle')
          else: print('Not in Rectangle')
        else: print('Not in Rectangle')

    def points_on_perimeter(self):
      for i in range(self.x, (self.x+self.__width)+1):
        ord_pair= ("(%d,%d)" %(i,self.y))
        self.__rec_points.append(ord_pair)
        ordpair= ("(%d,%d)" %(i,self.y+self.__length))
        self.__rec_points.append(ordpair)
        if len(self.__rec_points)>16:
          break

      for j in range(self.y, (self.y+self.__width)+1):
        t= ("(%d,%d)" %(self.x,j))
        self.__rec_points.append(t)
        r= ("(%d,%d)" %(self.x+self.__width,j))
        self.__rec_points.append(r)
        if len(self.__rec_points)>16:
          break

    def display_points(self):
      for e in self.__rec_points:
        print(e)

      
      
class triangle:
  def __init__(self,base,height):
    self.__base=base
    self.__height=height
  
  def tri_area(self):
    return (self.__base*self.__height)/2

  def parameter(self):
    return

# %%
rect=rectangle(0,0,3,10)
print(rect.perimeter())

rect.points_on_perimeter()
rect.display_points()
# Out:
# 26
# (0,0)
# (0,10)
# (1,0)
# (1,10)
# (2,0)
# (2,10)
# (3,0)
# (3,10)
# (0,0)
# (3,0)
# (0,1)
# (3,1)
# (0,2)
# (3,2)
# (0,3)
# (3,3)

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class coordinates:
  def __init__(self,x,y):
    self.x=x
    self.y=y

class circle(coordinates):
  def __init__(self,x,y,radius):
    super(circle,self).__init__(x,y)
    self.__radius=radius

  def cir_area(self):
    return 3.141592*((self.__radius)**2)

  def circumference(self):
    return 3.141592*(2*self.__radius)

  def in_circ(self,a,b):
    if (((a-self.x)**2)+((b-self.y)**2))**(1/2)<=self.__radius:
      print('In Circle')
    else: print('Not in Circle')


class rectangle(coordinates):
    def __init__(self,x,y,width,length):
        super(rectangle,self).__init__(x,y)
        self.__width=width
        self.__length=length
        self.__rec_points=list()
        
    def rec_area(self):
        return self.__width*self.__length
    
    def perimeter(self):
        return 2*(self.__width+self.__length)

    def in_rec(self,a,b):
        if a>=self.x and a<=self.x+self.__width:
          if b>=self.y and b<=self.y+self.__length:
            print('In Rectangle')
          else: print('Not in Rectangle')
        else: print('Not in Rectangle')

    def points_on_perimeter(self):
      for i in range(self.x, (self.x+self.__width)+1):
        ord_pair= ("(%d,%d)" %(i,self.y))
        self.__rec_points.append(ord_pair)
        ordpair= ("(%d,%d)" %(i,self.y+self.__length))
        self.__rec_points.append(ordpair)
        if len(self.__rec_points)>16:
          break

      for j in range(self.y, (self.y+self.__width)+1):
        t= ("(%d,%d)" %(self.x,j))
        self.__rec_points.append(t)
        r= ("(%d,%d)" %(self.x+self.__width,j))
        self.__rec_points.append(r)
        if len(self.__rec_points)>16:
          break

    def display_points(self):
      for e in self.__rec_points:
        print(e)

      
      
class triangle:
  def __init__(self,base,height):
    self.__base=base
    self.__height=height
  
  def tri_area(self):
    return (self.__base*self.__height)/2

  def parameter(self):
    return
