# %% [markdown]
# # Lab 3- Tic Tac Toe
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github//afarbin/DATA1401-Spring-2020/blob/master/Labs/Lab-3/Lab-3.ipynb)
#
# In this lab your will build a n x n Tic Tac Toe game. As you do the exercises, make sure your solutions work for any size Tic Tac Toe game.

# %% [markdown]
# *Exercise 1:* Write a function that creates an n by n matrix (of list of lists) which will represent the state of a Tie Tac Toe game. Let 0, 1, and 2 represent empty, "X", or "O".

# %%
# Write you solution here

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Test your solution here

# %%
# Index assignment for the matrix representation of the game board
player_1 = 1
player_2 = 2
empty = 0

# Game board size
size = 3

boardgame=list()
for i in range(size):
    boardgame.append([empty]*size)

# %%
# Test your solution here
boardgame[0][0]=1
boardgame
# Out:
# [[1, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# *Exercise 2:* Write a function that takes a `n` by `n` matrix representing a tic-tac-toe game, and returns -1, 0, 1, or 2 indicating the game is incomplete, the game is a draw, player 1 has won, or player 2 has one, respectively. Here are some example inputs you can use to test your code:

# %%
winner_is_2 = [[2, 0, 2],
	[2, 1, 0],
	[2, 1, 1]]

winner_is_1 = [[1, 2, 2],
	[2, 1, 2],
	[2, 1, 1]]

winner_is_also_1 = [[0, 1, 0],
	[2, 1, 0],
	[2, 1, 1]]

no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 2]]

also_no_winner = [[1, 2, 0],
	[2, 1, 0],
	[2, 1, 0]]

# %%
# Write you solution here
def win_indexes(n):
    # Rows
    for r in range(n):
        yield [(r, c) for c in range(n)]
    # Columns
    for c in range(n):
        yield [(r, c) for r in range(n)]
    # Diagonal top left to bottom right
    yield [(i, i) for i in range(n)]
    # Diagonal top right to bottom left
    yield [(i, n - 1 - i) for i in range(n)]

# %%
boardgame
def isthereemptyspaces(game):
  n=range(len(game))
  for x in n:
    for i in game[x]:
      if i==0:
        return True

# %%
isthereemptyspaces(boardgame)
# Out:
# True

# %%
def is_winner(board_game, decorator):
  if decorator==1:
    n = len(board_game)
    for indexes in win_indexes(n):
        if all(board_game[r][c] == decorator for r, c in indexes):
          return 1
    return False
  elif decorator==2:
    n = len(board_game)
    for indexes in win_indexes(n):
        if all(board_game[r][c] == decorator for r, c in indexes):
          return 2
    return False

# %%
# Test your solution here
is_winner(winner_is_also_1,2)
# Out:
# False

# %% [markdown]
# *Exercise 3:* Write a function that takes 2 integers `n` and `m` as input and draws a `n` by `m` game board. For example the following is a 3x3 board:
# ```
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#   |   |   |   |
#    --- --- ---
#    ```

# %%
# Write you solution here
def draw1(n,m):
    # initialize an empty board
    board = ""

    # there are 5 rows in a standard tic-tac-toe board
    for i in range(2*int(n)+1):
      # switch between printing vertical and horizontal bars
        if i%2 != 0:
            board += "|   " * n
            board += "|"
        else:
            board += " ---" * m
        # don't forget to start a new line after each row using "\n"
        board += "\n"

    Y= print(board)

# %%
# Test your solution here
draw1(3,3)
# Out:
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---
# |   |   |   |
#  --- --- ---

# %% [markdown]
# *Exercise 4:* Modify exercise 3, so that it takes a matrix of the form from exercise 2 and draws a tic-tac-tie board with "X"s and "O"s.

# %%
# Write you solution here
player_1_piece="X"
player_2_piece="O"
empty_space=" "

def space_character(player):
    if player==player_1:
        return player_1_piece
    elif player==player_2:
        return player_2_piece
    else:
        return empty_space

space_character= { player_1: player_1_piece,
                    player_2: player_2_piece,
                    empty: empty_space }

def draw_board(boardgame):
    for i in range(size):
        for j in range(size):
            print(space_character[boardgame[i][j]],end=" ")
        print()

# %%
# Write you solution here
def draw2(boardgame):
    # initialize an empty board
    board = ""

    # there are 5 rows in a standard tic-tac-toe board
    for i in range(2*int(size)+1):
        # switch between printing vertical and horizontal bars
        if i%2 != 0:
            board += ("| %s " %space_character[boardgame[int((int(i)/2)-.5)][0]]) 

            board += ("| %s " %space_character[boardgame[int((int(i)/2)-.5)][1]])

            board += ("| %s " %space_character[boardgame[int((int(i)/2)-.5)][2]])

            board += "|"
        else:
            board += " ---" * 3
        # don't forget to start a new line after each row using "\n"
        board += "\n"

    Y= print(board)

# %%
# Test your solution here
draw2(winner_is_also_1)
# Out:
#  --- --- ---
# |   | X |   |
#  --- --- ---
# | O | X |   |
#  --- --- ---
# | O | X | X |
#  --- --- ---

# %% [markdown]
# *Exercise 5:* Write a function that takes a game board, player number, and `(x,y)` coordinates and places "X" or "O" in the correct location of the game board. Make sure that you only allow filling previously empty locations. Return `True` or `False` to indicate successful placement of "X" or "O".

# %%
# Write you solution here
def tic(gb,player,x,y):
  n=range(len(gb))
  if player==1:
    for row in n:
      for column in gb[row]:
        if gb[x][y]==0:
          gb[x][y]=1
          return True
          print()
        if gb[x][y]!=0:
          return False
          print()
  if player==2:
    for row in n:
      for column in gb[row]:
        if gb[x][y]==0:
          gb[x][y]=2
          return True
          print()
        if gb[x][y]!=0:
          return False
          print()

# %%
# Test your solution here
tic(boardgame,1,1,1)
# Out:
# True

# %% [markdown]
# *Exercise 6:* Modify Exercise 4 to show column and row labels so that players can specify location using "A2" or "C1".

# %%
column_names=list(map(str,range(1,size+1)))
column_map=dict(zip(column_names,range(size)))


row_names=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")
row_map=dict(zip(row_names,range(size)))

row_map
# Out:
# {'A': 0, 'B': 1, 'C': 2}

# %%
column_map
# Out:
# {'1': 0, '2': 1, '3': 2}

# %%
# Write you solution here
def draw3(boardgame):
    # initialize an empty board
    board = ""
    col = "   "
    for j in range(size):
        col += (" %s  " %column_names[j])
    print(col)


    # there are 5 rows in a standard tic-tac-toe board
    for i in range(2*int(size)+1):
        # switch between printing vertical and horizontal bars
        if i%2 != 0:
            board += row_names[int(i-((i/2)+.5))]

            board += (" | %s " %space_character[boardgame[int((int(i)/2)-.5)][0]]) 

            board += ("| %s " %space_character[boardgame[int((int(i)/2)-.5)][1]])

            board += ("| %s " %space_character[boardgame[int((int(i)/2)-.5)][2]])

            board += "|"
        else:
            board += "   ---"

            board += " ---" *2
        # don't forget to start a new line after each row using "\n"
        board += "\n"

    Y= print(board)

# %%
# Test your solution here
draw3(boardgame)
# Out:
#     1   2   3
#    --- --- ---
# A |   |   |   |
#    --- --- ---
# B |   | X |   |
#    --- --- ---
# C |   |   |   |
#    --- --- ---

# %% [markdown]
# *Exercise 7:* Write a function that takes a board, player number, and location specified as in exercise 6 and then calls exercise 5 to correctly modify the board.

# %%
# Write you solution here
def tic2(gb,player,x,y,):
  n=range(len(gb))
  if player==1:
    for row in n:
      for column in gb[row]:
        if gb[x][y]==0:
          gb[x][y]=1
          return True
        if not gb[x][y]==0:
          return False

  if player==2:
    for row in n:
      for column in gb[row]:
        if gb[x][y]==0:
          gb[x][y]=2
          return True
        if not gb[x][y]==0:
          return False

# %%
def rowlocation(stwing):
  rowloc=stwing[0].upper()

  return row_map[rowloc]

# %%
def collocation(stwing):
  colloc=stwing[0].upper()

  return column_map[colloc]

# %%
def tictac(emptboard,playernum,string_1):
  x=rowlocation(string_1[0].upper())
  y=collocation(string_1[1].upper())

  if tic2(emptboard,playernum,x,y)==True:
    return True
  else:
    return False

# %%
# Test your solution here
tictac(boardgame,1,"a1")
# Out:
# True

# %% [markdown]
# *Exercise 8:* Write a function is called with a board and player number, takes input from the player using python's `input`, and modifies the board using your function from exercise 7. Note that you should keep asking for input until you have gotten a valid input that results in a valid move.

# %%
# Write you solution here
def tactoe(gameboard,playernumber):

  while not False:
    row= input("Player %s: Row Location=" %playernumber)
    column= input("Player %s: Column Location=" %playernumber)
    space= ("%s" %row + "%s" %column)
    
    good_move= tictac(gameboard,playernumber,space)
    if good_move== True:
      draw3(gameboard)
      break
    else:
      print("Invalid Location... Try again")
      continue

# %%
# Test your solution here
tactoe(boardgame,2)
# Out:
# Player 2: Row Location=c
# Player 2: Column Location=3
#     1   2   3
#    --- --- ---
# A | X |   |   |
#    --- --- ---
# B |   | X |   |
#    --- --- ---
# C |   |   | O |
#    --- --- ---

# %%
is_winner(boardgame,1)
# Out:
# False

# %% [markdown]
# *Exercise 9:* Use all of the previous exercises to implement a full tic-tac-toe game, where an appropriate board is drawn, 2 players are repeatedly asked for a location coordinates of where they wish to place a mark, and the game status is checked until a player wins or a draw occurs.

# %%
  # Index assignment for the matrix representation of the game board
  player_1 = 1
  player_2 = 2
  empty = 0

  # Game board size
  tictactoeboard=list()
  for i in range(size):
      tictactoeboard.append([empty]*size)

# %%
# Write you solution here
def tictactoe(size):

  print("Welcome to Tic-Tac-Toe")
  print("----------------------")

  #Make Empty Game Board
  draw3(tictactoeboard)

  #Start with Player 1
  playernumber = player_1

  open_spaces_available= True
  this_game_won = False
  
  while not this_game_won== player_2 and not this_game_won== player_1:
    
    #Player's Turn
    print("Player",playernumber,"move")
    tactoe(tictactoeboard,playernumber)

    #Check For Winner
    this_game_won = is_winner(tictactoeboard,playernumber)
    
    isthereemptyspaces(tictactoeboard)

    if not isthereemptyspaces(tictactoeboard)==True:
        print("The Game Ends in a Draw")
        this_game_won = "No one"
        break

    #Switch Players
    if playernumber==player_2:
      playernumber=player_1
    else:
      playernumber=player_2

  print("Winner is Player:",this_game_won)

# %%
# Test your solution here
tictactoe(3)
# Out:
# Welcome to Tic-Tac-Toe
# ----------------------
#     1   2   3
#    --- --- ---
# A |   |   |   |
#    --- --- ---
# B |   |   |   |
#    --- --- ---
# C |   |   |   |
#    --- --- ---
#
# Player 1 move
# Player 1: Row Location=a
# Player 1: Column Location=1
#     1   2   3
#    --- --- ---
# A | X |   |   |
#    --- --- ---
# B |   |   |   |
#    --- --- ---
# C |   |   |   |
#    --- --- ---
#
# Player 2 move
# Player 2: Row Location=a
# Player 2: Column Location=2
#     1   2   3
#    --- --- ---
# A | X | O |   |
#    --- --- ---
# B |   |   |   |
#    --- --- ---
# C |   |   |   |
#    --- --- ---
#
# Player 1 move
# Player 1: Row Location=a
# Player 1: Column Location=3
#     1   2   3
#    --- --- ---
# A | X | O | X |
#    --- --- ---
# B |   |   |   |
#    --- --- ---
# C |   |   |   |
#    --- --- ---
#
# Player 2 move
# Player 2: Row Location=b
# Player 2: Column Location=1
#     1   2   3
#    --- --- ---
# A | X | O | X |
#    --- --- ---
# B | O |   |   |
# ...

# %%
is_winner(tictactoeboard,1)
# Out:
# False

# %% [markdown]
# *Exercise 10:* Test that your game works for 5x5 Tic Tac Toe.

# %%
# Test your solution here

# %% [markdown]
# *Exercise 11: (Extra Credit)* Develop a version of the game where one player is the computer. Note that you don't need to do an extensive seach for the best move. You can have the computer simply protect against loosing and otherwise try to win with straight or diagonal patterns.

# %%
# Write you solution here

# %%
# Test your solution here
